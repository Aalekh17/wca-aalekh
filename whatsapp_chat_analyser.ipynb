# %%
import re
import pandas as pd

# %%
f=open('WhatsApp Chat with Abhijeet.txt',encoding='utf-8')

# %%
data=f.read()

# %%
print(data)

# %%
pattern='\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s-\s'
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# <>:1: SyntaxWarning: invalid escape sequence '\d'
# C:\Users\Aalekh Vishwakarma\AppData\Local\Temp\ipykernel_8180\3706297391.py:1: SyntaxWarning: invalid escape sequence '\d'
#   pattern='\d{1,2}/\d{1,2}/\d{2,4},\s\d{1,2}:\d{2}\s-\s'

# %%
messages=re.split(pattern,data)[1:]
messages

# %%
dates=re.findall(pattern,data)
dates

# %%
df=pd.DataFrame({'user_message':messages,'message_date':dates})

df['message_date']=pd.to_datetime(df['message_date'],format='%m/%d/%y, %H:%M - ')

df.rename(columns={'message_date':'date'},inplace=True)

df.head()
# Out:
#                                         user_message                date
# 0  Messages and calls are end-to-end encrypted. O... 2025-06-30 11:31:00
# 1  Aalekh Vishwakarma: Abhijeet generative ke maj... 2025-06-30 11:32:00
# 2                                    Abhijeet: Haa\n 2025-06-30 11:35:00
# 3  Aalekh Vishwakarma: Aree boolean me nhi, strin... 2025-06-30 11:37:00
# 4                          Abhijeet: Accha accha 😂\n 2025-06-30 12:36:00

# %%
df.shape
# Out:
# (521, 2)

# %%
users=[]
messages=[]
for message in df['user_message']:
    entry=re.split('([\w\W]+?):\s',message)
    if entry[1:]:
        users.append(entry[1])
        messages.append(entry[2])
    else:
        users.append('group_notifications')
        messages.append(entry[0])

df['user']=users
df['message']=messages
df.drop(columns=['user_message'],inplace=True)

df.head()
# Out:
# <>:4: SyntaxWarning: invalid escape sequence '\w'
# <>:4: SyntaxWarning: invalid escape sequence '\w'
# C:\Users\Aalekh Vishwakarma\AppData\Local\Temp\ipykernel_8180\3253716947.py:4: SyntaxWarning: invalid escape sequence '\w'
#   entry=re.split('([\w\W]+?):\s',message)
#                  date                 user  \
# 0 2025-06-30 11:31:00  group_notifications
# 1 2025-06-30 11:32:00   Aalekh Vishwakarma
# 2 2025-06-30 11:35:00             Abhijeet
# 3 2025-06-30 11:37:00   Aalekh Vishwakarma
# 4 2025-06-30 12:36:00             Abhijeet
#
#                                              message
# 0  Messages and calls are end-to-end encrypted. O...
# 1  Abhijeet generative ke major topics bata sakte...
# 2                                              Haa\n
# 3  Aree boolean me nhi, string me answer karna th...
# 4                                    Accha accha 😂\n

# %%
df['year']=df['date'].dt.year

# %%
df.head()
# Out:
#                  date                 user  \
# 0 2025-06-30 11:31:00  group_notifications
# 1 2025-06-30 11:32:00   Aalekh Vishwakarma
# 2 2025-06-30 11:35:00             Abhijeet
# 3 2025-06-30 11:37:00   Aalekh Vishwakarma
# 4 2025-06-30 12:36:00             Abhijeet
#
#                                              message  year month
# 0  Messages and calls are end-to-end encrypted. O...  2025  June
# 1  Abhijeet generative ke major topics bata sakte...  2025  June
# 2                                              Haa\n  2025  June
# 3  Aree boolean me nhi, string me answer karna th...  2025  June
# 4                                    Accha accha 😂\n  2025  June

# %%
df['month']=df['date'].dt.month_name()

# %%
df.head()
# Out:
#                  date                 user  \
# 0 2025-06-30 11:31:00  group_notifications
# 1 2025-06-30 11:32:00   Aalekh Vishwakarma
# 2 2025-06-30 11:35:00             Abhijeet
# 3 2025-06-30 11:37:00   Aalekh Vishwakarma
# 4 2025-06-30 12:36:00             Abhijeet
#
#                                              message  year month
# 0  Messages and calls are end-to-end encrypted. O...  2025  June
# 1  Abhijeet generative ke major topics bata sakte...  2025  June
# 2                                              Haa\n  2025  June
# 3  Aree boolean me nhi, string me answer karna th...  2025  June
# 4                                    Accha accha 😂\n  2025  June

# %%
df['day']=df['date'].dt.day

# %%
df.head()
# Out:
#                  date                 user  \
# 0 2025-06-30 11:31:00  group_notifications
# 1 2025-06-30 11:32:00   Aalekh Vishwakarma
# 2 2025-06-30 11:35:00             Abhijeet
# 3 2025-06-30 11:37:00   Aalekh Vishwakarma
# 4 2025-06-30 12:36:00             Abhijeet
#
#                                              message  year month  day
# 0  Messages and calls are end-to-end encrypted. O...  2025  June   30
# 1  Abhijeet generative ke major topics bata sakte...  2025  June   30
# 2                                              Haa\n  2025  June   30
# 3  Aree boolean me nhi, string me answer karna th...  2025  June   30
# 4                                    Accha accha 😂\n  2025  June   30

# %%
df['hour']=df['date'].dt.hour

# %%
df['minute']=df['date'].dt.minute

# %%
df.head()
# Out:
#                  date                 user  \
# 0 2025-06-30 11:31:00  group_notifications
# 1 2025-06-30 11:32:00   Aalekh Vishwakarma
# 2 2025-06-30 11:35:00             Abhijeet
# 3 2025-06-30 11:37:00   Aalekh Vishwakarma
# 4 2025-06-30 12:36:00             Abhijeet
#
#                                              message  year month  day  hour  \
# 0  Messages and calls are end-to-end encrypted. O...  2025  June   30    11
# 1  Abhijeet generative ke major topics bata sakte...  2025  June   30    11
# 2                                              Haa\n  2025  June   30    11
# 3  Aree boolean me nhi, string me answer karna th...  2025  June   30    11
# 4                                    Accha accha 😂\n  2025  June   30    12
#
#    minute
# 0      31
# 1      32
# 2      35
# 3      37
# 4      36
